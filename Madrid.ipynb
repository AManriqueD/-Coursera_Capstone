# %% [markdown]
# # Cultural trips
# We have a tourist business in the city of Madrid, we have found a good percentage of visitors are people in business trips with very little time to go out and enjoy the more interesting parts of the city. We are thinking about creating a service of short cultural trips so the businesspeople can see some of the city history and culture in their very limited time. This way, we need to find cultural places and hotels, where we are going to find our customers, that are close enough to the places they stay and we can provide a nice varied trip in a very small amount of time.

# %%
#Getting the libaries we are going to use first
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geopy.distance

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library
import wget

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Obtain the data

# %% [markdown]
# #### Location

# %% [markdown]
# We are based in the centre of the city of Madrid, so first we are going to get the geographical coordinates of the area

# %%
address = 'Madrid'

geolocator = Nominatim(user_agent="mad_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Madrid are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Madrid are 40.4167047, -3.7035825.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %% [markdown]
# To get the information of our cultural sites and hotels we are going to use Foursquare, so we introduce our acces information first

# %%
CLIENT_ID = 'HT0JPXUKRX3VMKPHIDMUOUH0R5ERT20UJ0UGNZHO1G0ZT3WK' # your Foursquare ID
CLIENT_SECRET = '2SWM32GS2354FUW4QG2ZRV2EE3ZFGOPSMAAVIGH3KHHFU4GS' # your Foursquare Secret
VERSION = '20180604' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HT0JPXUKRX3VMKPHIDMUOUH0R5ERT20UJ0UGNZHO1G0ZT3WK
# CLIENT_SECRET:2SWM32GS2354FUW4QG2ZRV2EE3ZFGOPSMAAVIGH3KHHFU4GS

# %% [markdown]
# #### Getting the venues of the area from Foursquare

# %% [markdown]
# We create the GET request URL.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 2000 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=HT0JPXUKRX3VMKPHIDMUOUH0R5ERT20UJ0UGNZHO1G0ZT3WK&client_secret=2SWM32GS2354FUW4QG2ZRV2EE3ZFGOPSMAAVIGH3KHHFU4GS&v=20180604&ll=40.4167047,-3.7035825&radius=2000&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ebf9e01211536001b8784ad'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Sol',
#   'headerFullLocation': 'Sol, Madrid',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 231,
#   'suggestedBounds': {'ne': {'lat': 40.43470471800001,
#     'lng': -3.6799843833873767},
#    'sw': {'lat': 40.39870468199998, 'lng': -3.7271806166126233}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a5201f3c21e3',
#        'name': 'Puerta del Sol',
#        'location': {'address': 'Pl. Puerta del Sol',
#         'lat': 40.4170267569777,
#         'lng': -3.703442763596807,
#         'distance': 37,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Puerta del Sol',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a5201f3c21e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5478dde0498eab68d4d6423f',
#        'name': 'Rosi La Loca',
#        'location': {'address': 'Calle Cadiz 4',
#         'lat': 40.415821011717526,
#         'lng': -3.7029546044326276,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.415821011717526,
#           'lng': -3.7029546044326276}],
#         'distance': 111,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Cadiz 4',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '136851529'}},
#       'referralId': 'e-0-5478dde0498eab68d4d6423f-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f33cbace4b0b5f6dee6d145',
#        'name': 'La Pulpería de Victoria',
#        'location': {'address': 'Calle de La Victoria, 2, (Junto a Puerta del Sol)',
#         'crossStreet': 'Carrera de San Jerónimo',
#         'lat': 40.416506381,
#         'lng': -3.70170887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416506381,
#           'lng': -3.70170887}],
#         'distance': 160,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de La Victoria, 2, (Junto a Puerta del Sol) (Carrera de San Jerónimo)',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f33cbace4b0b5f6dee6d145-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bddaac30ee3a59370242eb0',
#        'name': 'Club del Gourmet Corte Ingles',
#        'location': {'address': 'C. Preciados, 3',
#         'lat': 40.41749665225322,
#         'lng': -3.704686028127798,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41749665225322,
#           'lng': -3.704686028127798}],
#         'distance': 128,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Preciados, 3',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bddaac30ee3a59370242eb0-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54403f3b498e03786d6ef3bb',
#        'name': 'TOC Hostel',
#        'location': {'address': 'Plaza Celenque 3-5',
#         'lat': 40.41726434244726,
#         'lng': -3.7059281028464137,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41726434244726,
#           'lng': -3.7059281028464137}],
#         'distance': 208,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Plaza Celenque 3-5',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54403f3b498e03786d6ef3bb-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b72841ff964a520db7c2de3',
#        'name': 'Plaza de Santa Ana',
#        'location': {'address': 'Pl. de Santa Ana',
#         'lat': 40.41463076310542,
#         'lng': -3.7010325869307574,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41463076310542,
#           'lng': -3.7010325869307574}],
#         'distance': 316,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Santa Ana',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b72841ff964a520db7c2de3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5431272e498e8e357f694549',
#        'name': 'LUSH',
#        'location': {'address': 'Calle del Carmen 24',
#         'lat': 40.41901214762635,
#         'lng': -3.704898374374776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41901214762635,
#           'lng': -3.704898374374776}],
#         'distance': 280,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del Carmen 24',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5431272e498e8e357f694549-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5476a1ec498eb0f50cb79122',
#        'name': 'SunGate Hostel',
#        'location': {'address': 'Calle del Carmen, 16 - 2º Izq',
#         'lat': 40.41869565648317,
#         'lng': -3.7046225150264593,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41869565648317,
#           'lng': -3.7046225150264593}],
#         'distance': 238,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del Carmen, 16 - 2º Izq',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5476a1ec498eb0f50cb79122-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57756e14498e605edcad54fc',
#        'name': 'Salmon Gurú',
#        'location': {'address': 'C. Echegaray, 21',
#         'lat': 40.41486660560401,
#         'lng': -3.6995319613728506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41486660560401,
#           'lng': -3.6995319613728506}],
#         'distance': 399,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Echegaray, 21',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57756e14498e605edcad54fc-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50accc51e4b03cc0bd939c5a',
#        'name': 'Gourmet Experience',
#        'location': {'address': 'Pl. Callao, 2, 9º',
#         'lat': 40.41966660972929,
#         'lng': -3.7054582485281027,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41966660972929,
#           'lng': -3.7054582485281027}],
#         'distance': 366,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Callao, 2, 9º',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50accc51e4b03cc0bd939c5a-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b59799ff964a520778928e3',
#        'name': 'Plaza del Callao',
#        'location': {'address': 'Pl. del Callao',
#         'lat': 40.42014480521912,
#         'lng': -3.705762832193117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42014480521912,
#           'lng': -3.705762832193117}],
#         'distance': 425,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. del Callao',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b59799ff964a520778928e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '538a4c78498e264f18c776b2',
#        'name': 'Apple Puerta del Sol',
#        'location': {'address': 'Plaza De La Puerta Del Sol, 1',
#         'crossStreet': 'C. Alcalá',
#         'lat': 40.41689826118782,
#         'lng': -3.702065348625183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41689826118782,
#           'lng': -3.702065348625183}],
#         'distance': 130,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Plaza De La Puerta Del Sol, 1 (C. Alcalá)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-538a4c78498e264f18c776b2-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7eaa51f964a52008f82fe3',
#        'name': 'La Cabaña Argentina',
#        'location': {'address': 'C. Ventura de la Vega, 10',
#         'crossStreet': 'C. Carrera de San Jerónimo',
#         'lat': 40.415696026060175,
#         'lng': -3.6989742057930957,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.415696026060175,
#           'lng': -3.6989742057930957}],
#         'distance': 406,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Ventura de la Vega, 10 (C. Carrera de San Jerónimo)',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d107941735',
#          'name': 'Argentinian Restaurant',
#          'pluralName': 'Argentinian Restaurants',
#          'shortName': 'Argentinian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7eaa51f964a52008f82fe3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a520193c21e3',
#        'name': 'Plaza Mayor',
#        'location': {'address': 'Pl. Mayor',
#         'lat': 40.415526598647354,
#         'lng': -3.7075061894121037,
#         'distance': 357,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Mayor', '28012 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a520193c21e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ed8bfa646907c1b40950ccf',
#        'name': 'Imprenta Municipal',
#        'location': {'address': 'C. Concepción Jerónima, 15',
#         'lat': 40.413663321236676,
#         'lng': -3.705447800535241,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.413663321236676,
#           'lng': -3.705447800535241}],
#         'distance': 373,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Concepción Jerónima, 15',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ed8bfa646907c1b40950ccf-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53106df211d2057452905bb1',
#        'name': 'The Hat Madrid',
#        'location': {'address': 'Imperial 9',
#         'lat': 40.414342796030915,
#         'lng': -3.70712009092247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.414342796030915,
#           'lng': -3.70712009092247}],
#         'distance': 398,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Imperial 9', '28012 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53106df211d2057452905bb1-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5108e3d129a6465f856837dc',
#        'name': 'La Taberna de Mister Pinkleton',
#        'location': {'address': 'Cuchilleros, 7',
#         'lat': 40.414535529593635,
#         'lng': -3.708108373041791,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.414535529593635,
#           'lng': -3.708108373041791}],
#         'distance': 453,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Cuchilleros, 7',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11a941735',
#          'name': 'Other Nightlife',
#          'pluralName': 'Other Nightlife',
#          'shortName': 'Nightlife',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50440659'}},
#       'referralId': 'e-0-5108e3d129a6465f856837dc-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5815186538faca7f0db08a89',
#        'name': 'La Primera',
#        'location': {'address': 'Gran Vía, 1',
#         'lat': 40.41918268290716,
#         'lng': -3.697793514240437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41918268290716,
#           'lng': -3.697793514240437}],
#         'distance': 562,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Gran Vía, 1', '28013 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5815186538faca7f0db08a89-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a9b656498e4e4ac3c16de8',
#        'name': 'Gran Vía Capital',
#        'location': {'address': 'Calle Gran Vía 48',
#         'lat': 40.42069333275565,
#         'lng': -3.7064598025941797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42069333275565,
#           'lng': -3.7064598025941797}],
#         'distance': 506,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Gran Vía 48',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a9b656498e4e4ac3c16de8-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3cf964a5208d3d21e3',
#        'name': 'Teatro de La Zarzuela',
#        'location': {'address': 'Calle de Jovellanos, 4',
#         'lat': 40.41718415347722,
#         'lng': -3.6970549821853633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41718415347722,
#           'lng': -3.6970549821853633}],
#         'distance': 555,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Jovellanos, 4',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda3cf964a5208d3d21e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0372fa310fc9b691f3c561',
#        'name': 'Way Hostel',
#        'location': {'address': 'Calle del Relatores, 17',
#         'lat': 40.41263845574944,
#         'lng': -3.7033413990304274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41263845574944,
#           'lng': -3.7033413990304274}],
#         'distance': 453,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del Relatores, 17',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '62216305'}},
#       'referralId': 'e-0-4c0372fa310fc9b691f3c561-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5289cbc111d2b04c75f0824f',
#        'name': 'El Imparcial',
#        'location': {'address': 'C. Duque de Alba, 4',
#         'lat': 40.411928907144485,
#         'lng': -3.7057817062423974,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.411928907144485,
#           'lng': -3.7057817062423974}],
#         'distance': 563,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Duque de Alba, 4',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5289cbc111d2b04c75f0824f-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda33f964a520a53a21e3',
#        'name': 'Gran Meliá Palacio de los Duques *****',
#        'location': {'address': 'Cuesta de Santo Domingo, 5',
#         'lat': 40.41983538326362,
#         'lng': -3.7094940649977075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41983538326362,
#           'lng': -3.7094940649977075}],
#         'distance': 610,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Cuesta de Santo Domingo, 5',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda33f964a520a53a21e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bafc459d4cc98002ccfb0a5',
#        'name': 'Ferreteria By Ego',
#        'location': {'address': '57 Calle de Atocha',
#         'lat': 40.412558,
#         'lng': -3.699631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.412558,
#           'lng': -3.699631}],
#         'distance': 570,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['57 Calle de Atocha',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bafc459d4cc98002ccfb0a5-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f71852498e58358ab9f8f1',
#        'name': 'Fogg Birra and Cheese',
#        'location': {'address': 'C. de Moratín, 5',
#         'lat': 40.41227536098442,
#         'lng': -3.69798791617441,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41227536098442,
#           'lng': -3.69798791617441}],
#         'distance': 684,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'neighborhood': 'Huertas',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Moratín, 5',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f71852498e58358ab9f8f1-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5877d4aed4ab730fcf09092b',
#        'name': 'Toga',
#        'location': {'address': 'Calle Juanelo 23',
#         'lat': 40.41111841899132,
#         'lng': -3.70667299456038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41111841899132,
#           'lng': -3.70667299456038}],
#         'distance': 674,
#         'postalCode': '28008',
#         'cc': 'ES',
#         'neighborhood': 'Lavapiés',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Juanelo 23',
#          '28008 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5877d4aed4ab730fcf09092b-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59a1e62a4c954c5afe5b6b4a',
#        'name': 'Giolatto',
#        'location': {'lat': 40.41289120242951,
#         'lng': -3.700055684503051,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41289120242951,
#           'lng': -3.700055684503051}],
#         'distance': 519,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28012 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59a1e62a4c954c5afe5b6b4a-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a2043c21fa76357f07e23ae',
#        'name': 'Sala Equis',
#        'location': {'address': 'Duque de Alba',
#         'lat': 40.41218953407115,
#         'lng': -3.7060283550885944,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41218953407115,
#           'lng': -3.7060283550885944}],
#         'distance': 543,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Duque de Alba',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'shortName': 'Indie Movies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a2043c21fa76357f07e23ae-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '590a200caa6c9535c594574b',
#        'name': 'The Brunch Club',
#        'location': {'address': 'Calle del barco 25',
#         'lat': 40.42161192764877,
#         'lng': -3.7027903662919144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42161192764877,
#           'lng': -3.7027903662919144}],
#         'distance': 550,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Universidad',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del barco 25',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-590a200caa6c9535c594574b-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b557dfff964a520a4e527e3',
#        'name': 'Cine Doré',
#        'location': {'address': 'C. Santa Isabel, 3',
#         'lat': 40.41183256074677,
#         'lng': -3.6992668712271692,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41183256074677,
#           'lng': -3.6992668712271692}],
#         'distance': 654,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Santa Isabel, 3',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b557dfff964a520a4e527e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f2d2e4ae4b0124ab827520d',
#        'name': 'Yoka Loka',
#        'location': {'address': 'C. Santa Isabel, 5',
#         'crossStreet': 'mercado de Antón Martín,  pto. 81 planta baja',
#         'lat': 40.41161458501999,
#         'lng': -3.698692811574475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41161458501999,
#           'lng': -3.698692811574475}],
#         'distance': 702,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Santa Isabel, 5 (mercado de Antón Martín,  pto. 81 planta baja)',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f2d2e4ae4b0124ab827520d-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3cf964a5208c3d21e3',
#        'name': 'Teatro Real de Madrid',
#        'location': {'address': 'Pl. de Isabel II',
#         'lat': 40.41822583203057,
#         'lng': -3.7110644324883078,
#         'distance': 656,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'neighborhood': 'Opera',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Isabel II',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d136941735',
#          'name': 'Opera House',
#          'pluralName': 'Opera Houses',
#          'shortName': 'Opera House',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_operahouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda3cf964a5208c3d21e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '554c9690498ef7cacc2d2ee5',
#        'name': 'ok hostel',
#        'location': {'lat': 40.411135489335344,
#         'lng': -3.7068188834260543,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.411135489335344,
#           'lng': -3.7068188834260543}],
#         'distance': 677,
#         'cc': 'ES',
#         'neighborhood': 'Lavapiés',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-554c9690498ef7cacc2d2ee5-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a5201e3c21e3',
#        'name': 'Plaza de la Villa',
#        'location': {'address': 'Pl. de la Villa',
#         'lat': 40.415408601788656,
#         'lng': -3.710390924213192,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.415408601788656,
#           'lng': -3.710390924213192}],
#         'distance': 594,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de la Villa',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a5201e3c21e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '566db21b498e3f66283b240c',
#        'name': 'Libreria Cafe El Dinosaurio Todavia Estaba Alli',
#        'location': {'address': 'Ave Maria 8',
#         'lat': 40.41167506219228,
#         'lng': -3.700300547654981,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41167506219228,
#           'lng': -3.700300547654981}],
#         'distance': 625,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Ave Maria 8', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-566db21b498e3f66283b240c-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a5200d3c21e3',
#        'name': 'Museo Thyssen-Bornemisza',
#        'location': {'address': 'P. del Prado, 8',
#         'lat': 40.41635928605382,
#         'lng': -3.6948908136558845,
#         'distance': 737,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['P. del Prado, 8',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '39916041'}},
#       'referralId': 'e-0-4adcda37f964a5200d3c21e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a520203c21e3',
#        'name': 'Plaza de Oriente',
#        'location': {'address': 'Pl. de Oriente',
#         'lat': 40.418325668437966,
#         'lng': -3.712196052074432,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.418325668437966,
#           'lng': -3.712196052074432}],
#         'distance': 751,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Oriente',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a520203c21e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '590a03309de23b6c4297c320',
#        'name': 'Plenti',
#        'location': {'address': 'Costanilla de los Desamparados, 13',
#         'lat': 40.41213451312291,
#         'lng': -3.696623656621767,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41213451312291,
#           'lng': -3.696623656621767}],
#         'distance': 778,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'neighborhood': 'Huertas',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Costanilla de los Desamparados, 13',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '574612575'}},
#       'referralId': 'e-0-590a03309de23b6c4297c320-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57360ba5498e1cea71c891af',
#        'name': 'Bee Beer',
#        'location': {'address': 'C. Augusto Figueroa, 30',
#         'lat': 40.421952,
#         'lng': -3.6969,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421952,
#           'lng': -3.6969}],
#         'distance': 813,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid City Center',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Augusto Figueroa, 30',
#          '28004 Madrid Centro Madrid',
#          'España']},
#        'categories': [{'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'shortName': 'Beer Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57360ba5498e1cea71c891af-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e524d43814d5634cb17faf7',
#        'name': 'El Rey León, El Musical',
#        'location': {'address': 'Gran Vía 57',
#         'lat': 40.42151046064538,
#         'lng': -3.708903833873936,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42151046064538,
#           'lng': -3.708903833873936}],
#         'distance': 699,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Gran Vía 57', '28014 Madrid Madrid', 'España']},
#        'categories': [{'id': '5267e4d9e4b0ec79466e48c8',
#          'name': 'Other Event',
#          'pluralName': 'Other Events',
#          'shortName': 'Other Event',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/event/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e524d43814d5634cb17faf7-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2cd572f964a520b0c924e3',
#        'name': 'El Mollete',
#        'location': {'address': 'C. La Bola, 4',
#         'lat': 40.419912891328146,
#         'lng': -3.710502973556587,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.419912891328146,
#           'lng': -3.710502973556587}],
#         'distance': 686,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. La Bola, 4',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
# ...
#         'distance': 954,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Espíritu Santo, 12',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db859c64b22f2ddb63a14d7-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda38f964a5206f3c21e3',
#        'name': 'Plaza de Cascorro',
#        'location': {'address': 'Pl. de Cascorro',
#         'lat': 40.41073737202163,
#         'lng': -3.7072268844252787,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41073737202163,
#           'lng': -3.7072268844252787}],
#         'distance': 732,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Cascorro',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda38f964a5206f3c21e3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5081c670e4b0e99d0aecea35',
#        'name': 'El Estudio de los Arquitectos',
#        'location': {'address': 'C. Costanilla de San Pedro, 9',
#         'lat': 40.41252736670137,
#         'lng': -3.710673020549052,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41252736670137,
#           'lng': -3.710673020549052}],
#         'distance': 759,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Costanilla de San Pedro, 9',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5081c670e4b0e99d0aecea35-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a520fd3b21e3',
#        'name': 'Museo Nacional del Prado',
#        'location': {'address': 'C. de Ruiz de Alarcón, 23',
#         'crossStreet': 'P. del Prado',
#         'lat': 40.413978006085095,
#         'lng': -3.6921894550323486,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.413978006085095,
#           'lng': -3.6921894550323486}],
#         'distance': 1012,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Ruiz de Alarcón, 23 (P. del Prado)',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a520fd3b21e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c83aa355ba0460037d55b2d',
#        'name': 'Museo del Prado 1819-2019: Un Lugar de Memoria',
#        'location': {'address': 'C. de Ruiz de Alarcón, 23',
#         'lat': 40.41424910503363,
#         'lng': -3.6923718452453613,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41424910503363,
#           'lng': -3.6923718452453613}],
#         'distance': 988,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Ruiz de Alarcón, 23',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '56aa371be4b08b9a8d573532',
#          'name': 'Exhibit',
#          'pluralName': 'Exhibits',
#          'shortName': 'Exhibit',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c83aa355ba0460037d55b2d-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '556c8d53498e9ace8382361f',
#        'name': 'Motteau',
#        'location': {'address': 'San Pedro',
#         'crossStreet': 'Gobernador',
#         'lat': 40.41161292170898,
#         'lng': -3.694798032133308,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41161292170898,
#           'lng': -3.694798032133308}],
#         'distance': 935,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['San Pedro (Gobernador)',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0a',
#          'name': 'Pie Shop',
#          'pluralName': 'Pie Shops',
#          'shortName': 'Pie Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pieshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-556c8d53498e9ace8382361f-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be2ff6cd27a20a1adf1905b',
#        'name': 'Chopper Monster',
#        'location': {'address': 'Corredera Alta de San Pablo, 21',
#         'lat': 40.42584619831552,
#         'lng': -3.7018201527200567,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42584619831552,
#           'lng': -3.7018201527200567}],
#         'distance': 1028,
#         'postalCode': '28045',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Corredera Alta de San Pablo, 21',
#          '28045 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be2ff6cd27a20a1adf1905b-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb3a143e4b0947c3d6a4831',
#        'name': 'Movilonia.com',
#        'location': {'address': 'Calle Donoso Cortés, 8',
#         'lat': 40.42643713828792,
#         'lng': -3.7054036112477533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42643713828792,
#           'lng': -3.7054036112477533}],
#         'distance': 1094,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Donoso Cortés, 8',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#          'name': 'Mobile Phone Shop',
#          'pluralName': 'Mobile Phone Shops',
#          'shortName': 'Mobile Phones',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '38088998'}},
#       'referralId': 'e-0-4fb3a143e4b0947c3d6a4831-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5457d5b3498e9c0e13cee664',
#        'name': 'Pajaritos Mojados',
#        'location': {'address': 'C. Humilladero, 3',
#         'lat': 40.4105244385695,
#         'lng': -3.710317211965421,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4105244385695,
#           'lng': -3.710317211965421}],
#         'distance': 893,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Humilladero, 3',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5457d5b3498e9c0e13cee664-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53b5ba78498e41ea4e231ee4',
#        'name': 'DSTAgE',
#        'location': {'address': 'C. Regueros, 8',
#         'lat': 40.42472945683953,
#         'lng': -3.6963052685894597,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42472945683953,
#           'lng': -3.6963052685894597}],
#         'distance': 1085,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Regueros, 8',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53b5ba78498e41ea4e231ee4-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c48f6d498e6709893c65f0',
#        'name': 'Mar&Ola',
#        'location': {'address': 'Almendro 25',
#         'lat': 40.412110647922,
#         'lng': -3.7106201645978993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.412110647922,
#           'lng': -3.7106201645978993}],
#         'distance': 785,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Almendro 25', '28005 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51c48f6d498e6709893c65f0-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac924f0a22db76045072b51',
#        'name': 'Charrua',
#        'location': {'lat': 40.422416,
#         'lng': -3.693999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.422416,
#           'lng': -3.693999}],
#         'distance': 1031,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ac924f0a22db76045072b51-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d78b524a56e3704ed146f67',
#        'name': 'Plaza de Platería de Martínez',
#        'location': {'address': 'C/ de las Huertas',
#         'crossStreet': 'C/ de Moratín',
#         'lat': 40.41282827347961,
#         'lng': -3.693618280493645,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41282827347961,
#           'lng': -3.693618280493645}],
#         'distance': 948,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ de las Huertas (C/ de Moratín)',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d78b524a56e3704ed146f67-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4d0165e4b05ebee45e1480',
#        'name': 'Eric Vökel Boutique Apartments',
#        'location': {'address': 'C. San Bernardo, 61',
#         'lat': 40.42629146021611,
#         'lng': -3.706962739482536,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42629146021611,
#           'lng': -3.706962739482536}],
#         'distance': 1104,
#         'postalCode': '28015',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. San Bernardo, 61',
#          '28015 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '46926624'}},
#       'referralId': 'e-0-4f4d0165e4b05ebee45e1480-99'}]}]}}

# %% [markdown]
# The most important information we need is the categories of the venues and their location to get their distances.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json and structure it into a *pandas* dataframe.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                             name          categories        lat       lng
# 0                 Puerta del Sol               Plaza  40.417027 -3.703443
# 1                   Rosi La Loca    Tapas Restaurant  40.415821 -3.702955
# 2        La Pulpería de Victoria  Seafood Restaurant  40.416506 -3.701709
# 3  Club del Gourmet Corte Ingles        Gourmet Shop  40.417497 -3.704686
# 4                     TOC Hostel              Hostel  40.417264 -3.705928

# %% [markdown]
# We check all the unique type of venues we have

# %%
nearby_venues['categories'].unique()
# Out:
# array(['Plaza', 'Tapas Restaurant', 'Seafood Restaurant', 'Gourmet Shop',
#        'Hostel', 'Cosmetics Shop', 'Cocktail Bar', 'Electronics Store',
#        'Argentinian Restaurant', 'History Museum', 'Hotel',
#        'Other Nightlife', 'Restaurant', 'Theater', 'Bistro', 'Pub',
#        'Spanish Restaurant', 'Ice Cream Shop', 'Indie Movie Theater',
#        'Café', 'Movie Theater', 'Sushi Restaurant', 'Opera House',
#        'Historic Site', 'Art Museum', 'Beer Store', 'Other Event',
#        'Bookstore', 'Miscellaneous Shop', 'Food & Drink Shop',
#        'American Restaurant', 'Gastropub', 'Mediterranean Restaurant',
#        'Road', 'Department Store', 'Bar', 'Coffee Shop', 'Dessert Shop',
#        'Market', 'Pizza Place', 'Fountain', 'Candy Store', 'Garden',
#        'Palace', 'Peruvian Restaurant', 'Exhibit', 'Pie Shop',
#        'Clothing Store', 'Mobile Phone Shop', 'BBQ Joint'], dtype=object)

# %% [markdown]
# For our new bussiness we are going to focus first in just hotels in the centre, so we get a dataset for them

# %%
hotels = nearby_venues[nearby_venues.categories == 'Hotel']
hotels
# Out:
#                                       name categories        lat       lng
# 15                          The Hat Madrid      Hotel  40.414343 -3.707120
# 18                        Gran Vía Capital      Hotel  40.420693 -3.706460
# 22  Gran Meliá Palacio de los Duques *****      Hotel  40.419835 -3.709494
# 74                   Only YOU Hotel&Lounge      Hotel  40.422227 -3.695762
# 99          Eric Vökel Boutique Apartments      Hotel  40.426291 -3.706963

# %% [markdown]
# Now we get another dataset for the cultural spaces

# %%
List = ['Plaza', 'Theater', 'History Museum','Performing Arts Venue','Historic Site','Monument / Landmark', 'Museum','Opera House']
cultural_sites = nearby_venues.loc[nearby_venues['categories'].isin(List)]
cultural_sites
# Out:
#                              name      categories        lat       lng
# 0                  Puerta del Sol           Plaza  40.417027 -3.703443
# 5              Plaza de Santa Ana           Plaza  40.414631 -3.701033
# 10               Plaza del Callao           Plaza  40.420145 -3.705763
# 13                    Plaza Mayor           Plaza  40.415527 -3.707506
# 14             Imprenta Municipal  History Museum  40.413663 -3.705448
# 19          Teatro de La Zarzuela         Theater  40.417184 -3.697055
# 31          Teatro Real de Madrid     Opera House  40.418226 -3.711064
# 33              Plaza de la Villa   Historic Site  40.415409 -3.710391
# 36               Plaza de Oriente           Plaza  40.418326 -3.712196
# 62              Teatro Del Barrio         Theater  40.409666 -3.699222
# 67          Plaza de Antón Martín           Plaza  40.412454 -3.699466
# 69               Plaza de Cibeles           Plaza  40.419191 -3.693117
# 75                Plaza de Chueca           Plaza  40.422724 -3.697588
# 87              Plaza de Cascorro           Plaza  40.410737 -3.707227
# 98  Plaza de Platería de Martínez           Plaza  40.412828 -3.693618

# %% [markdown]
# With all the data we need for our calculations we show the venues in a map. We can se the hotels in dark blue and the cultural sites in red

# %%
#We create map of Madrid using latitude and longitude values
map_madrid = folium.Map(location=[latitude, longitude], zoom_start=15)

# adding hotel markers to map
for lat, lng, name, in zip(hotels['lat'], hotels['lng'], hotels['name']):
    label1 = '{}'.format(name)
    label1 = folium.Popup(label1, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label1,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_madrid)  
# adding cultural venues markers to map
for lat, lng, ven_names, venues in zip (cultural_sites['lat'], cultural_sites['lng'],cultural_sites['name'], cultural_sites['categories']):
    label2 = '{}'.format(ven_names, venues)
    label2 = folium.Popup(label2, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label2,
        color='red',
        fill=True,
        fill_color='#FFB0B0',
        fill_opacity=0.7,
        parse_html=False).add_to(map_madrid)  
    
map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. Calculations
# Our objective now is obtaining several clusters of cultural sites using the distances to the hotels we have

# %% [markdown]
# #### Distances
# First we get the distances beteween the hotels and the cultural sites

# %%
y=[]   
for i in range(len(hotels)):
    hot_coor = hotels.iloc[i,2:]
    x=[]
    for index, row in cultural_sites.iterrows():
        cul_coor = (row.lat, row.lng)
        x.append(geopy.distance.distance(hot_coor, cul_coor).m)
    y.append(x)
Distances_df = pd.DataFrame(y, columns=cultural_sites.name)
Distances_df = Distances_df.transpose().reset_index()
Distances_df
# Out:
#                              name            0            1            2  \
# 0                  Puerta del Sol   431.550900   480.970538   600.855950
# 1              Plaza de Santa Ana   517.667297   815.701918   921.811080
# 2                Plaza del Callao   654.487561    84.904619   318.522294
# 3                     Plaza Mayor   135.475621   580.560595   507.333451
# 4              Imprenta Municipal   160.745016   785.342108   766.587303
# 5           Teatro de La Zarzuela   910.666234   888.222946  1095.988431
# 6           Teatro Real de Madrid   545.882969   477.275769   222.949848
# 7               Plaza de la Villa   301.785952   675.043882   497.420077
# 8                Plaza de Oriente   617.414391   553.286370   284.060047
# 9               Teatro Del Barrio   847.946520  1369.899474  1426.575550
# 10          Plaza de Antón Martín   682.623707  1090.559925  1181.570276
# 11               Plaza de Cibeles  1304.721516  1144.585713  1391.728549
# 12                Plaza de Chueca  1233.123526   785.935037  1060.097696
# 13              Plaza de Cascorro   400.458150  1107.451447  1028.429389
# 14  Plaza de Platería de Martínez  1158.259986  1396.644461  1555.948466
#
#               3            4
# 0    870.887810  1071.271376
# 1    954.822297  1389.204399
# 2    879.704958   690.095862
# 3   1243.847724  1196.249062
# 4   1257.039562  1408.144663
# 5    570.665827  1315.191856
# 6   1372.624287   960.895771
# 7   1454.246928  1242.991444
# 8   1460.493660   989.781027
# 9   1425.387382  1959.489567
# 10  1129.869302  1663.027418
# 11   405.008072  1415.007656
# 12   164.538965   888.706821
# 13  1604.604611  1727.313212
# 14  1059.434257  1875.530647

# %%
cultural_sites_latlng = cultural_sites.loc[:,'lat':'lng'].reset_index()
Distances_latlng = Distances_df.join(cultural_sites_latlng.drop(['index'], axis=1))
Distances_latlng
# Out:
#                              name            0            1            2  \
# 0                  Puerta del Sol   431.550900   480.970538   600.855950
# 1              Plaza de Santa Ana   517.667297   815.701918   921.811080
# 2                Plaza del Callao   654.487561    84.904619   318.522294
# 3                     Plaza Mayor   135.475621   580.560595   507.333451
# 4              Imprenta Municipal   160.745016   785.342108   766.587303
# 5           Teatro de La Zarzuela   910.666234   888.222946  1095.988431
# 6           Teatro Real de Madrid   545.882969   477.275769   222.949848
# 7               Plaza de la Villa   301.785952   675.043882   497.420077
# 8                Plaza de Oriente   617.414391   553.286370   284.060047
# 9               Teatro Del Barrio   847.946520  1369.899474  1426.575550
# 10          Plaza de Antón Martín   682.623707  1090.559925  1181.570276
# 11               Plaza de Cibeles  1304.721516  1144.585713  1391.728549
# 12                Plaza de Chueca  1233.123526   785.935037  1060.097696
# 13              Plaza de Cascorro   400.458150  1107.451447  1028.429389
# 14  Plaza de Platería de Martínez  1158.259986  1396.644461  1555.948466
#
#               3            4        lat       lng
# 0    870.887810  1071.271376  40.417027 -3.703443
# 1    954.822297  1389.204399  40.414631 -3.701033
# 2    879.704958   690.095862  40.420145 -3.705763
# 3   1243.847724  1196.249062  40.415527 -3.707506
# 4   1257.039562  1408.144663  40.413663 -3.705448
# 5    570.665827  1315.191856  40.417184 -3.697055
# 6   1372.624287   960.895771  40.418226 -3.711064
# 7   1454.246928  1242.991444  40.415409 -3.710391
# 8   1460.493660   989.781027  40.418326 -3.712196
# 9   1425.387382  1959.489567  40.409666 -3.699222
# 10  1129.869302  1663.027418  40.412454 -3.699466
# 11   405.008072  1415.007656  40.419191 -3.693117
# 12   164.538965   888.706821  40.422724 -3.697588
# 13  1604.604611  1727.313212  40.410737 -3.707227
# 14  1059.434257  1875.530647  40.412828 -3.693618

# %% [markdown]
# Adding the names for better identification and the coordinates to represent them later in the map

# %%
hotels_names = hotels.loc[:,'name']
hotels_names
Distances_latlng.columns.values[1:6]= hotels_names
Distances = Distances_latlng
Distances
# Out:
#                              name  The Hat Madrid  Gran Vía Capital  \
# 0                  Puerta del Sol      431.550900        480.970538
# 1              Plaza de Santa Ana      517.667297        815.701918
# 2                Plaza del Callao      654.487561         84.904619
# 3                     Plaza Mayor      135.475621        580.560595
# 4              Imprenta Municipal      160.745016        785.342108
# 5           Teatro de La Zarzuela      910.666234        888.222946
# 6           Teatro Real de Madrid      545.882969        477.275769
# 7               Plaza de la Villa      301.785952        675.043882
# 8                Plaza de Oriente      617.414391        553.286370
# 9               Teatro Del Barrio      847.946520       1369.899474
# 10          Plaza de Antón Martín      682.623707       1090.559925
# 11               Plaza de Cibeles     1304.721516       1144.585713
# 12                Plaza de Chueca     1233.123526        785.935037
# 13              Plaza de Cascorro      400.458150       1107.451447
# 14  Plaza de Platería de Martínez     1158.259986       1396.644461
#
#     Gran Meliá Palacio de los Duques *****  Only YOU Hotel&Lounge  \
# 0                               600.855950             870.887810
# 1                               921.811080             954.822297
# 2                               318.522294             879.704958
# 3                               507.333451            1243.847724
# 4                               766.587303            1257.039562
# 5                              1095.988431             570.665827
# 6                               222.949848            1372.624287
# 7                               497.420077            1454.246928
# 8                               284.060047            1460.493660
# 9                              1426.575550            1425.387382
# 10                             1181.570276            1129.869302
# 11                             1391.728549             405.008072
# 12                             1060.097696             164.538965
# 13                             1028.429389            1604.604611
# 14                             1555.948466            1059.434257
#
#     Eric Vökel Boutique Apartments        lat       lng
# 0                      1071.271376  40.417027 -3.703443
# 1                      1389.204399  40.414631 -3.701033
# 2                       690.095862  40.420145 -3.705763
# 3                      1196.249062  40.415527 -3.707506
# 4                      1408.144663  40.413663 -3.705448
# 5                      1315.191856  40.417184 -3.697055
# 6                       960.895771  40.418226 -3.711064
# 7                      1242.991444  40.415409 -3.710391
# 8                       989.781027  40.418326 -3.712196
# 9                      1959.489567  40.409666 -3.699222
# 10                     1663.027418  40.412454 -3.699466
# 11                     1415.007656  40.419191 -3.693117
# 12                      888.706821  40.422724 -3.697588
# 13                     1727.313212  40.410737 -3.707227
# 14                     1875.530647  40.412828 -3.693618

# %% [markdown]
# #### Clusters

# %%
# set number of clusters
kclusters = 5
Distances_fit =  Distances_df.drop(columns=['name'])
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Distances_fit)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:15]
# Out:
# array([1, 1, 4, 1, 1, 2, 4, 1, 4, 3, 0, 2, 2, 0, 3])

# %%
# add clustering labels
Distances.insert(0, 'Cluster Labels', kmeans.labels_)
Distances
# Out:
#     Cluster Labels                           name  The Hat Madrid  \
# 0                1                 Puerta del Sol      431.550900
# 1                1             Plaza de Santa Ana      517.667297
# 2                4               Plaza del Callao      654.487561
# 3                1                    Plaza Mayor      135.475621
# 4                1             Imprenta Municipal      160.745016
# 5                2          Teatro de La Zarzuela      910.666234
# 6                4          Teatro Real de Madrid      545.882969
# 7                1              Plaza de la Villa      301.785952
# 8                4               Plaza de Oriente      617.414391
# 9                3              Teatro Del Barrio      847.946520
# 10               0          Plaza de Antón Martín      682.623707
# 11               2               Plaza de Cibeles     1304.721516
# 12               2                Plaza de Chueca     1233.123526
# 13               0              Plaza de Cascorro      400.458150
# 14               3  Plaza de Platería de Martínez     1158.259986
#
#     Gran Vía Capital  Gran Meliá Palacio de los Duques *****  \
# 0         480.970538                              600.855950
# 1         815.701918                              921.811080
# 2          84.904619                              318.522294
# 3         580.560595                              507.333451
# 4         785.342108                              766.587303
# 5         888.222946                             1095.988431
# 6         477.275769                              222.949848
# 7         675.043882                              497.420077
# 8         553.286370                              284.060047
# 9        1369.899474                             1426.575550
# 10       1090.559925                             1181.570276
# 11       1144.585713                             1391.728549
# 12        785.935037                             1060.097696
# 13       1107.451447                             1028.429389
# 14       1396.644461                             1555.948466
#
#     Only YOU Hotel&Lounge  Eric Vökel Boutique Apartments        lat       lng
# 0              870.887810                     1071.271376  40.417027 -3.703443
# 1              954.822297                     1389.204399  40.414631 -3.701033
# 2              879.704958                      690.095862  40.420145 -3.705763
# 3             1243.847724                     1196.249062  40.415527 -3.707506
# 4             1257.039562                     1408.144663  40.413663 -3.705448
# 5              570.665827                     1315.191856  40.417184 -3.697055
# 6             1372.624287                      960.895771  40.418226 -3.711064
# 7             1454.246928                     1242.991444  40.415409 -3.710391
# 8             1460.493660                      989.781027  40.418326 -3.712196
# 9             1425.387382                     1959.489567  40.409666 -3.699222
# 10            1129.869302                     1663.027418  40.412454 -3.699466
# 11             405.008072                     1415.007656  40.419191 -3.693117
# 12             164.538965                      888.706821  40.422724 -3.697588
# 13            1604.604611                     1727.313212  40.410737 -3.707227
# 14            1059.434257                     1875.530647  40.412828 -3.693618

# %% [markdown]
# ### 3. Results

# %% [markdown]
# We show the clusters in a map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=15)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Distances['lat'], Distances['lng'], Distances['name'], Distances['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
# add hotel markers to map
for lat, lng, name, in zip(hotels['lat'], hotels['lng'], hotels['name']):
    label1 = '{}'.format(name)
    label1 = folium.Popup(label1, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label1,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)  
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
