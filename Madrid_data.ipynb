# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library
import wget

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Download and Explore Dataset

# %% [markdown]
# #### Load  the data

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>mad_explorer</em>, as shown below.

# %%
address = 'Madrid'

geolocator = Nominatim(user_agent="mad_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Madrid are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Madrid are 40.4167047, -3.7035825.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'HT0JPXUKRX3VMKPHIDMUOUH0R5ERT20UJ0UGNZHO1G0ZT3WK' # your Foursquare ID
CLIENT_SECRET = '2SWM32GS2354FUW4QG2ZRV2EE3ZFGOPSMAAVIGH3KHHFU4GS' # your Foursquare Secret
VERSION = '20180604' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HT0JPXUKRX3VMKPHIDMUOUH0R5ERT20UJ0UGNZHO1G0ZT3WK
# CLIENT_SECRET:2SWM32GS2354FUW4QG2ZRV2EE3ZFGOPSMAAVIGH3KHHFU4GS

# %% [markdown]
# #### Let's explore the first neighborhood in our dataframe.

# %% [markdown]
# First, let's create the GET request URL. Name your URL **url**.

# %%
# type your answer here
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 2000 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=HT0JPXUKRX3VMKPHIDMUOUH0R5ERT20UJ0UGNZHO1G0ZT3WK&client_secret=2SWM32GS2354FUW4QG2ZRV2EE3ZFGOPSMAAVIGH3KHHFU4GS&v=20180604&ll=40.4167047,-3.7035825&radius=2000&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e917e2bc94979001bdf1320'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Sol',
#   'headerFullLocation': 'Sol, Madrid',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 238,
#   'suggestedBounds': {'ne': {'lat': 40.43470471800001,
#     'lng': -3.6799843833873767},
#    'sw': {'lat': 40.39870468199998, 'lng': -3.7271806166126233}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a5201f3c21e3',
#        'name': 'Puerta del Sol',
#        'location': {'address': 'Pl. Puerta del Sol',
#         'lat': 40.4170267569777,
#         'lng': -3.703442763596807,
#         'distance': 37,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Puerta del Sol',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a5201f3c21e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bddaac30ee3a59370242eb0',
#        'name': 'Club del Gourmet Corte Ingles',
#        'location': {'address': 'C. Preciados, 3',
#         'lat': 40.41749665225322,
#         'lng': -3.704686028127798,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41749665225322,
#           'lng': -3.704686028127798}],
#         'distance': 128,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Preciados, 3',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bddaac30ee3a59370242eb0-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5478dde0498eab68d4d6423f',
#        'name': 'Rosi La Loca',
#        'location': {'address': 'Calle Cadiz 4',
#         'lat': 40.415821011717526,
#         'lng': -3.7029546044326276,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.415821011717526,
#           'lng': -3.7029546044326276}],
#         'distance': 111,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Cadiz 4',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '136851529'}},
#       'referralId': 'e-0-5478dde0498eab68d4d6423f-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f33cbace4b0b5f6dee6d145',
#        'name': 'La Pulpería de Victoria',
#        'location': {'address': 'Calle de La Victoria, 2, (Junto a Puerta del Sol)',
#         'crossStreet': 'Carrera de San Jerónimo',
#         'lat': 40.416506381,
#         'lng': -3.70170887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416506381,
#           'lng': -3.70170887}],
#         'distance': 160,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de La Victoria, 2, (Junto a Puerta del Sol) (Carrera de San Jerónimo)',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f33cbace4b0b5f6dee6d145-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '538a4c78498e264f18c776b2',
#        'name': 'Apple Puerta del Sol',
#        'location': {'address': 'Plaza De La Puerta Del Sol, 1',
#         'crossStreet': 'C. Alcalá',
#         'lat': 40.41689826118782,
#         'lng': -3.702065348625183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41689826118782,
#           'lng': -3.702065348625183}],
#         'distance': 130,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Plaza De La Puerta Del Sol, 1 (C. Alcalá)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-538a4c78498e264f18c776b2-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b72841ff964a520db7c2de3',
#        'name': 'Plaza de Santa Ana',
#        'location': {'address': 'Pl. de Santa Ana',
#         'lat': 40.41463076310542,
#         'lng': -3.7010325869307574,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41463076310542,
#           'lng': -3.7010325869307574}],
#         'distance': 316,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Santa Ana',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b72841ff964a520db7c2de3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5374c6ff498eb7fa65ba2f4a',
#        'name': 'TAKOS',
#        'location': {'address': 'C. Abada, 2',
#         'lat': 40.418938,
#         'lng': -3.703748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.418938,
#           'lng': -3.703748}],
#         'distance': 249,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Abada, 2', '28013 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5374c6ff498eb7fa65ba2f4a-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5431272e498e8e357f694549',
#        'name': 'LUSH',
#        'location': {'address': 'Calle del Carmen 24',
#         'lat': 40.41901214762635,
#         'lng': -3.704898374374776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41901214762635,
#           'lng': -3.704898374374776}],
#         'distance': 280,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del Carmen 24',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5431272e498e8e357f694549-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a520193c21e3',
#        'name': 'Plaza Mayor',
#        'location': {'address': 'Pl. Mayor',
#         'lat': 40.415526598647354,
#         'lng': -3.7075061894121037,
#         'distance': 357,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Mayor', '28012 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a520193c21e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57756e14498e605edcad54fc',
#        'name': 'Salmon Gurú',
#        'location': {'address': 'C. Echegaray, 21',
#         'lat': 40.41486660560401,
#         'lng': -3.6995319613728506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41486660560401,
#           'lng': -3.6995319613728506}],
#         'distance': 399,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Echegaray, 21',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57756e14498e605edcad54fc-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c09679d7e3fc928edeaf182',
#        'name': 'Museo del Jamón',
#        'location': {'address': 'C. Mayor, 7',
#         'lat': 40.416343036500216,
#         'lng': -3.7056822482813363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416343036500216,
#           'lng': -3.7056822482813363}],
#         'distance': 182,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Mayor, 7', '28013 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c09679d7e3fc928edeaf182-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7eaa51f964a52008f82fe3',
#        'name': 'La Cabaña Argentina',
#        'location': {'address': 'C. Ventura de la Vega, 10',
#         'crossStreet': 'C. Carrera de San Jerónimo',
#         'lat': 40.415696026060175,
#         'lng': -3.6989742057930957,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.415696026060175,
#           'lng': -3.6989742057930957}],
#         'distance': 406,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Ventura de la Vega, 10 (C. Carrera de San Jerónimo)',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d107941735',
#          'name': 'Argentinian Restaurant',
#          'pluralName': 'Argentinian Restaurants',
#          'shortName': 'Argentinian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7eaa51f964a52008f82fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50accc51e4b03cc0bd939c5a',
#        'name': 'Gourmet Experience',
#        'location': {'address': 'Pl. Callao, 2, 9º',
#         'lat': 40.41966660972929,
#         'lng': -3.7054582485281027,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41966660972929,
#           'lng': -3.7054582485281027}],
#         'distance': 366,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Callao, 2, 9º',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50accc51e4b03cc0bd939c5a-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5638f1e3cd10cb685f484c8e',
#        'name': 'Myst Gym Club',
#        'location': {'address': 'Calle Mayor, 6',
#         'lat': 40.41647661391564,
#         'lng': -3.7053298415720475,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41647661391564,
#           'lng': -3.7053298415720475}],
#         'distance': 150,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Mayor, 6',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5638f1e3cd10cb685f484c8e-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8818d5f964a5208cdf31e3',
#        'name': 'La Mallorquina',
#        'location': {'address': 'C. Mayor, 2',
#         'crossStreet': 'Pl. de la Puerta del Sol',
#         'lat': 40.416651463931025,
#         'lng': -3.7046623706905586,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416651463931025,
#           'lng': -3.7046623706905586}],
#         'distance': 91,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Mayor, 2 (Pl. de la Puerta del Sol)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4e2',
#          'name': 'Pastry Shop',
#          'pluralName': 'Pastry Shops',
#          'shortName': 'Pastry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8818d5f964a5208cdf31e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdd9af2df986ea876a5d616',
#        'name': 'Hotel NH Collection Madrid Palacio de Tepa',
#        'location': {'address': 'C. San Sebastián, 2',
#         'lat': 40.41379972837331,
#         'lng': -3.7016755766313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41379972837331,
#           'lng': -3.7016755766313}],
#         'distance': 361,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. San Sebastián, 2',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdd9af2df986ea876a5d616-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53106df211d2057452905bb1',
#        'name': 'The Hat Madrid',
#        'location': {'address': 'Imperial 9',
#         'lat': 40.414342796030915,
#         'lng': -3.70712009092247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.414342796030915,
#           'lng': -3.70712009092247}],
#         'distance': 398,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Imperial 9', '28012 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53106df211d2057452905bb1-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b59799ff964a520778928e3',
#        'name': 'Plaza del Callao',
#        'location': {'address': 'Pl. del Callao',
#         'lat': 40.42014480521912,
#         'lng': -3.705762832193117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42014480521912,
#           'lng': -3.705762832193117}],
#         'distance': 425,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. del Callao',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b59799ff964a520778928e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5108e3d129a6465f856837dc',
#        'name': 'La Taberna de Mister Pinkleton',
#        'location': {'address': 'Cuchilleros, 7',
#         'lat': 40.414535529593635,
#         'lng': -3.708108373041791,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.414535529593635,
#           'lng': -3.708108373041791}],
#         'distance': 453,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Cuchilleros, 7',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11a941735',
#          'name': 'Other Nightlife',
#          'pluralName': 'Other Nightlife',
#          'shortName': 'Nightlife',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50440659'}},
#       'referralId': 'e-0-5108e3d129a6465f856837dc-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b814342f964a520a49c30e3',
#        'name': 'Trattoria Malatesta',
#        'location': {'address': 'C. Coloreros, 5',
#         'crossStreet': 'C. Mayor',
#         'lat': 40.416788,
#         'lng': -3.707182,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416788,
#           'lng': -3.707182}],
#         'distance': 305,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'neighborhood': 'Sol',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Coloreros, 5 (C. Mayor)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33104611'}},
#       'referralId': 'e-0-4b814342f964a520a49c30e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda40f964a5206e3e21e3',
#        'name': 'Mercado de San Miguel',
#        'location': {'address': 'Pl. de San Miguel',
#         'lat': 40.41544294871344,
#         'lng': -3.708943462311585,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41544294871344,
#           'lng': -3.708943462311585}],
#         'distance': 475,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de San Miguel',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda40f964a5206e3e21e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3ef964a5204c3e21e3',
#        'name': 'Fnac',
#        'location': {'address': 'C. Preciados, 28',
#         'lat': 40.41917587046351,
#         'lng': -3.705268692635151,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41917587046351,
#           'lng': -3.705268692635151}],
#         'distance': 309,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Preciados, 28',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda3ef964a5204c3e21e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0372fa310fc9b691f3c561',
#        'name': 'Way Hostel',
#        'location': {'address': 'Calle del Relatores, 17',
#         'lat': 40.41263845574944,
#         'lng': -3.7033413990304274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41263845574944,
#           'lng': -3.7033413990304274}],
#         'distance': 453,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del Relatores, 17',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '62216305'}},
#       'referralId': 'e-0-4c0372fa310fc9b691f3c561-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda35f964a5207d3b21e3',
#        'name': 'Chocolatería San Ginés',
#        'location': {'address': 'C. Pasadizo de San Ginés, 5',
#         'crossStreet': 'C. Arenal',
#         'lat': 40.416754336997364,
#         'lng': -3.7070788402276738,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.416754336997364,
#           'lng': -3.7070788402276738}],
#         'distance': 296,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Pasadizo de San Ginés, 5 (C. Arenal)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '75544207'}},
#       'referralId': 'e-0-4adcda35f964a5207d3b21e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5815186538faca7f0db08a89',
#        'name': 'La Primera',
#        'location': {'address': 'Gran Vía, 1',
#         'lat': 40.41918268290716,
#         'lng': -3.697793514240437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41918268290716,
#           'lng': -3.697793514240437}],
#         'distance': 562,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Gran Vía, 1', '28013 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5815186538faca7f0db08a89-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57a9b656498e4e4ac3c16de8',
#        'name': 'Gran Vía Capital',
#        'location': {'address': 'Calle Gran Vía 48',
#         'lat': 40.42069333275565,
#         'lng': -3.7064598025941797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42069333275565,
#           'lng': -3.7064598025941797}],
#         'distance': 506,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Gran Vía 48',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57a9b656498e4e4ac3c16de8-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3cf964a5208d3d21e3',
#        'name': 'Teatro de La Zarzuela',
#        'location': {'address': 'Calle de Jovellanos, 4',
#         'lat': 40.41718415347722,
#         'lng': -3.6970549821853633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41718415347722,
#           'lng': -3.6970549821853633}],
#         'distance': 555,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Jovellanos, 4',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda3cf964a5208d3d21e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53ce9a52498e0eaa7ccfb45f',
#        'name': 'El Jardín Secreto de SB',
#        'location': {'address': 'C. Montera, 37 - 4ª Planta',
#         'lat': 40.419106710663684,
#         'lng': -3.7023069232360086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.419106710663684,
#           'lng': -3.7023069232360086}],
#         'distance': 288,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Montera, 37 - 4ª Planta',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53ce9a52498e0eaa7ccfb45f-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a2043c21fa76357f07e23ae',
#        'name': 'Sala Equis',
#        'location': {'address': 'Duque de Alba',
#         'lat': 40.41218953407115,
#         'lng': -3.7060283550885944,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41218953407115,
#           'lng': -3.7060283550885944}],
#         'distance': 543,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Duque de Alba',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'shortName': 'Indie Movies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a2043c21fa76357f07e23ae-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bafc459d4cc98002ccfb0a5',
#        'name': 'Ferreteria By Ego',
#        'location': {'address': '57 Calle de Atocha',
#         'lat': 40.412558,
#         'lng': -3.699631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.412558,
#           'lng': -3.699631}],
#         'distance': 570,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['57 Calle de Atocha',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bafc459d4cc98002ccfb0a5-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59a1e62a4c954c5afe5b6b4a',
#        'name': 'Giolatto',
#        'location': {'lat': 40.41289120242951,
#         'lng': -3.700055684503051,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41289120242951,
#           'lng': -3.700055684503051}],
#         'distance': 519,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['28012 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59a1e62a4c954c5afe5b6b4a-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5289cbc111d2b04c75f0824f',
#        'name': 'El Imparcial',
#        'location': {'address': 'C. Duque de Alba, 4',
#         'lat': 40.411928907144485,
#         'lng': -3.7057817062423974,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.411928907144485,
#           'lng': -3.7057817062423974}],
#         'distance': 563,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Duque de Alba, 4',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5289cbc111d2b04c75f0824f-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a5201e3c21e3',
#        'name': 'Plaza de la Villa',
#        'location': {'address': 'Pl. de la Villa',
#         'lat': 40.415408601788656,
#         'lng': -3.710390924213192,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.415408601788656,
#           'lng': -3.710390924213192}],
#         'distance': 594,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de la Villa',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a5201e3c21e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda33f964a520a53a21e3',
#        'name': 'Gran Meliá Palacio de los Duques *****',
#        'location': {'address': 'Cuesta de Santo Domingo, 5',
#         'lat': 40.41983538326362,
#         'lng': -3.7094940649977075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41983538326362,
#           'lng': -3.7094940649977075}],
#         'distance': 610,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Cuesta de Santo Domingo, 5',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda33f964a520a53a21e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf6e9484a67c92852a922cf',
#        'name': 'Palacio Santa Ana',
#        'location': {'address': 'Plaza del Angel',
#         'lat': 40.414382390474,
#         'lng': -3.701874586944422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.414382390474,
#           'lng': -3.701874586944422}],
#         'distance': 296,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Plaza del Angel', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf6e9484a67c92852a922cf-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ff9e7c6fd626300708b2ab',
#        'name': 'Federal Café 2',
#        'location': {'address': 'Plaza Conde de Barajas 3',
#         'lat': 40.41445972417601,
#         'lng': -3.7087736699569414,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41445972417601,
#           'lng': -3.7087736699569414}],
#         'distance': 505,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'neighborhood': 'La Latina',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Plaza Conde de Barajas 3',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58ff9e7c6fd626300708b2ab-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b22b7d9916bc1002c7454f3',
#        'name': 'Generator Madrid',
#        'location': {'address': 'C. San Bernardo, 2',
#         'lat': 40.42072911693891,
#         'lng': -3.7081056833267207,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42072911693891,
#           'lng': -3.7081056833267207}],
#         'distance': 589,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. San Bernardo, 2',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b22b7d9916bc1002c7454f3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5877d4aed4ab730fcf09092b',
#        'name': 'Toga',
#        'location': {'address': 'Calle Juanelo 23',
#         'lat': 40.41111841899132,
#         'lng': -3.70667299456038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41111841899132,
#           'lng': -3.70667299456038}],
#         'distance': 674,
#         'postalCode': '28008',
#         'cc': 'ES',
#         'neighborhood': 'Lavapiés',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Juanelo 23',
#          '28008 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5877d4aed4ab730fcf09092b-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a3c837e3fc9284639f382',
#        'name': 'Librería de Montaña - Desnivel',
#        'location': {'address': 'Matute, 6',
#         'lat': 40.41335167974752,
#         'lng': -3.6998780050890727,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41335167974752,
#           'lng': -3.6998780050890727}],
#         'distance': 487,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Matute, 6', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0a3c837e3fc9284639f382-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda38f964a5204c3c21e3',
#        'name': 'Círculo de Bellas Artes',
#        'location': {'address': 'C. Alcalá, 42',
#         'lat': 40.41848647958846,
#         'lng': -3.6966117471456528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41848647958846,
#           'lng': -3.6966117471456528}],
#         'distance': 623,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Alcalá, 42',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda38f964a5204c3c21e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda35f964a5205a3b21e3',
#        'name': 'Casa Patas',
#        'location': {'address': 'C. Cañizares, 10',
#         'lat': 40.41267737917284,
#         'lng': -3.7017365524042884,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41267737917284,
#           'lng': -3.7017365524042884}],
#         'distance': 474,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Cañizares, 10',
#          '28012 Madrid Madrid',
#          'España']},
# ...
#           'lng': -3.713126238343502}],
#         'distance': 886,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Bailén, 2', '28013 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'shortName': 'Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1e4ede8b3aa5932bd99b5f-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '525aa32e11d2a8e48e87e77e',
#        'name': 'Los Porfiados',
#        'location': {'address': 'C. Buenavista, 18',
#         'crossStreet': 'C. Torrecilla del Leal',
#         'lat': 40.410110365834385,
#         'lng': -3.698907434582576,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.410110365834385,
#           'lng': -3.698907434582576}],
#         'distance': 834,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Buenavista, 18 (C. Torrecilla del Leal)',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d107941735',
#          'name': 'Argentinian Restaurant',
#          'pluralName': 'Argentinian Restaurants',
#          'shortName': 'Argentinian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-525aa32e11d2a8e48e87e77e-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda37f964a5200e3c21e3',
#        'name': 'Palacio Real de Madrid',
#        'location': {'address': 'C. Bailén, s/n',
#         'crossStreet': 'Pl. de Oriente',
#         'lat': 40.41793972010854,
#         'lng': -3.714258670806885,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41793972010854,
#           'lng': -3.714258670806885}],
#         'distance': 915,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Bailén, s/n (Pl. de Oriente)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a14',
#          'name': 'Palace',
#          'pluralName': 'Palaces',
#          'shortName': 'Palace',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda37f964a5200e3c21e3-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda38f964a520703c21e3',
#        'name': 'Plaza de Cibeles',
#        'location': {'address': 'Pl. de Cibeles',
#         'lat': 40.41919125282064,
#         'lng': -3.6931171834789165,
#         'distance': 929,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Cibeles',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda38f964a520703c21e3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52307d2711d25277dedb26b1',
#        'name': 'Restaurante Lily',
#        'location': {'address': 'Mercado de los Mostenses',
#         'crossStreet': 'Pza. Mostenses 1',
#         'lat': 40.42311435242576,
#         'lng': -3.709037008777121,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42311435242576,
#           'lng': -3.709037008777121}],
#         'distance': 850,
#         'postalCode': '28015',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Mercado de los Mostenses (Pza. Mostenses 1)',
#          '28015 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4eb1bfa43b7b52c0e1adc2e8',
#          'name': 'Peruvian Restaurant',
#          'pluralName': 'Peruvian Restaurants',
#          'shortName': 'Peruvian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/peruvian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52307d2711d25277dedb26b1-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c459b4454a9074a8002bb3',
#        'name': 'Only YOU Hotel&Lounge',
#        'location': {'address': 'Calle del Barquillo, 21',
#         'lat': 40.422227356410346,
#         'lng': -3.6957616908073305,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.422227356410346,
#           'lng': -3.6957616908073305}],
#         'distance': 904,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle del Barquillo, 21',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '68154892'}},
#       'referralId': 'e-0-51c459b4454a9074a8002bb3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda38f964a520643c21e3',
#        'name': 'Plaza de Chueca',
#        'location': {'address': 'Pl. de Chueca',
#         'lat': 40.422724108271076,
#         'lng': -3.697588319370037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.422724108271076,
#           'lng': -3.697588319370037}],
#         'distance': 840,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Chueca',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda38f964a520643c21e3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5729117b498e20da9ba19ca3',
#        'name': 'López & López',
#        'location': {'address': 'Calle Cabestreros, 4',
#         'lat': 40.40949877800912,
#         'lng': -3.7040456799697785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.40949877800912,
#           'lng': -3.7040456799697785}],
#         'distance': 803,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Cabestreros, 4',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '197179242'}},
#       'referralId': 'e-0-5729117b498e20da9ba19ca3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a714befb9d897f0fab03b0',
#        'name': 'Zero Point Coffee Shop',
#        'location': {'lat': 40.409925433621694,
#         'lng': -3.696936332307282,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.409925433621694,
#           'lng': -3.696936332307282}],
#         'distance': 941,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58a714befb9d897f0fab03b0-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c98adf707916dcb52faed1b',
#        'name': 'La Tragantúa',
#        'location': {'address': 'C. Verónica, 4',
#         'crossStreet': 'C. Fúcar',
#         'lat': 40.41184555400155,
#         'lng': -3.6954076239854836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41184555400155,
#           'lng': -3.6954076239854836}],
#         'distance': 879,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Verónica, 4 (C. Fúcar)',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c98adf707916dcb52faed1b-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd4271b607a6dcb9bc71354',
#        'name': 'Plaza Cánovas del Castillo',
#        'location': {'address': 'Pl. Cánovas del Castillo',
#         'lat': 40.415268651941545,
#         'lng': -3.6941850185394287,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.415268651941545,
#           'lng': -3.6941850185394287}],
#         'distance': 812,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Cánovas del Castillo',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd4271b607a6dcb9bc71354-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda38f964a520523c21e3',
#        'name': 'Santa Iglesia Catedral de Santa María la Real de la Almudena (Catedral de la Almudena)',
#        'location': {'address': 'C. Bailén, 8-10',
#         'lat': 40.41576693264202,
#         'lng': -3.7145161628723145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41576693264202,
#           'lng': -3.7145161628723145}],
#         'distance': 932,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Bailén, 8-10',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adcda38f964a520523c21e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53a9b3f3498e5a0355498970',
#        'name': 'La Pasteleria Del Duque',
#        'location': {'address': 'Calle Duque de Alba, 1',
#         'lat': 40.41164381531476,
#         'lng': -3.7067959166347375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41164381531476,
#           'lng': -3.7067959166347375}],
#         'distance': 625,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle Duque de Alba, 1',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53a9b3f3498e5a0355498970-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '513918df8acabb546c08a9dc',
#        'name': 'Casa Pachuco',
#        'location': {'address': 'C. Tres Peces, 15',
#         'lat': 40.41082162929018,
#         'lng': -3.6994234493363587,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41082162929018,
#           'lng': -3.6994234493363587}],
#         'distance': 743,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Tres Peces, 15',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1db931735',
#          'name': 'Tapas Restaurant',
#          'pluralName': 'Tapas Restaurants',
#          'shortName': 'Tapas',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-513918df8acabb546c08a9dc-99'}]}]}}

# %% [markdown]
# The information is in the *items* key.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json and structure it into a *pandas* dataframe.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                             name          categories        lat       lng
# 0                 Puerta del Sol               Plaza  40.417027 -3.703443
# 1  Club del Gourmet Corte Ingles        Gourmet Shop  40.417497 -3.704686
# 2                   Rosi La Loca    Tapas Restaurant  40.415821 -3.702955
# 3        La Pulpería de Victoria  Seafood Restaurant  40.416506 -3.701709
# 4           Apple Puerta del Sol   Electronics Store  40.416898 -3.702065

# %% [markdown]
# We check what type of venues we have

# %%
nearby_venues['categories'].unique()
# Out:
# array(['Plaza', 'Gourmet Shop', 'Tapas Restaurant', 'Seafood Restaurant',
#        'Electronics Store', 'Mexican Restaurant', 'Cosmetics Shop',
#        'Cocktail Bar', 'Spanish Restaurant', 'Argentinian Restaurant',
#        'Gym', 'Pastry Shop', 'Hotel', 'Other Nightlife',
#        'Italian Restaurant', 'Market', 'Hostel', 'Chocolate Shop',
#        'Restaurant', 'Theater', 'Café', 'Indie Movie Theater',
#        'Ice Cream Shop', 'Bistro', 'Historic Site',
#        'Gym / Fitness Center', 'Bookstore', 'Monument / Landmark',
#        'Performing Arts Venue', 'Pub', 'Roof Deck', 'Sushi Restaurant',
#        'Opera House', 'Movie Theater', 'Art Museum', 'Coffee Shop',
#        'Miscellaneous Shop', 'Church', 'Pizza Place',
#        'Mediterranean Restaurant', 'Clothing Store', 'Other Event',
#        'Food & Drink Shop', 'Beer Bar', 'Beer Store',
#        'American Restaurant', 'Vegetarian / Vegan Restaurant', 'Road',
#        'Candy Store', 'Wine Bar', 'Garden', 'Palace',
#        'Peruvian Restaurant', 'Dessert Shop'], dtype=object)

# %% [markdown]
# We get a data set for the hotels in Madrid

# %%
hotels = nearby_venues[nearby_venues.categories == 'Hotel']
hotels
# Out:
#                                           name categories        lat       lng
# 15  Hotel NH Collection Madrid Palacio de Tepa      Hotel  40.413800 -3.701676
# 16                              The Hat Madrid      Hotel  40.414343 -3.707120
# 25                            Gran Vía Capital      Hotel  40.420693 -3.706460
# 33      Gran Meliá Palacio de los Duques *****      Hotel  40.419835 -3.709494
# 55                       Room Mate Óscar Hotel      Hotel  40.420664 -3.699170
# 91                       Only YOU Hotel&Lounge      Hotel  40.422227 -3.695762

# %% [markdown]
# Now we get another data set for cultural spaces

# %%
List = ['Plaza', 'Theater', 'History Museum','Performing Arts Venue','Historic Site','Monument / Landmark', 'Museum','Opera House']
cultural_sites = nearby_venues.loc[nearby_venues['categories'].isin(List)]
cultural_sites
# Out:
#                           name             categories        lat       lng
# 0               Puerta del Sol                  Plaza  40.417027 -3.703443
# 5           Plaza de Santa Ana                  Plaza  40.414631 -3.701033
# 8                  Plaza Mayor                  Plaza  40.415527 -3.707506
# 17            Plaza del Callao                  Plaza  40.420145 -3.705763
# 26       Teatro de La Zarzuela                Theater  40.417184 -3.697055
# 32           Plaza de la Villa          Historic Site  40.415409 -3.710391
# 39     Círculo de Bellas Artes    Monument / Landmark  40.418486 -3.696612
# 40                  Casa Patas  Performing Arts Venue  40.412677 -3.701737
# 46       Teatro Real de Madrid            Opera House  40.418226 -3.711064
# 51            Plaza de Oriente                  Plaza  40.418326 -3.712196
# 75       Plaza de Antón Martín                  Plaza  40.412454 -3.699466
# 84           Teatro Del Barrio                Theater  40.409666 -3.699222
# 89            Plaza de Cibeles                  Plaza  40.419191 -3.693117
# 92             Plaza de Chueca                  Plaza  40.422724 -3.697588
# 96  Plaza Cánovas del Castillo                  Plaza  40.415269 -3.694185

# %% [markdown]
# We show the venues we have in a map

# %%
# create map of Madrid using latitude and longitude values
map_madrid = folium.Map(location=[latitude, longitude], zoom_start=15)

# add hotel markers to map
for lat, lng, name, in zip(hotels['lat'], hotels['lng'], hotels['name']):
    label1 = '{}'.format(name)
    label1 = folium.Popup(label1, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label1,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_madrid)  
# add cultural venues markers to map
for lat, lng, ven_names, venues in zip (cultural_sites['lat'], cultural_sites['lng'],cultural_sites['name'], cultural_sites['categories']):
    label2 = '{}'.format(ven_names, venues)
    label2 = folium.Popup(label2, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label2,
        color='red',
        fill=True,
        fill_color='#FFB0B0',
        fill_opacity=0.7,
        parse_html=False).add_to(map_madrid)  
    
map_madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
